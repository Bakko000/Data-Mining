# %%
#Scatter plot prima tra duration_ms e dance
# Poi portare duration_ms in secondi e float a 2 vedi se la correlazione rimane

# %%
import pandas as pd
import seaborn as sns
import scipy as sp
import math
import matplotlib.pyplot as plt
from plotly.offline import iplot
from scipy.spatial.distance import cosine
from plotly.offline import iplot
import plotly as py
import cufflinks as cf
import math 
import numpy as np
#py.offline.init_notebook_mode(connected=True) 
#cf.go_offline()

# %%
df=pd.read_csv('train.csv', skipinitialspace=True)

# %%
sns.regplot(x='danceability', y='duration_ms', fit_reg=True, data=df)
# Out:
# <Axes: xlabel='danceability', ylabel='duration_ms'>

# %%
sns.regplot(y='danceability', x='duration_ms', fit_reg=True, data=df)

# %%
df['duration_ms'] = df['duration_ms'].apply(lambda x: x/1000)
sns.regplot(y='danceability', x='duration_ms', fit_reg=True, data=df)
# Out:
# <Axes: xlabel='duration_ms', ylabel='danceability'>
