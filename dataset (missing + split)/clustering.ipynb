# %%
import pandas as pd
import seaborn as sns
import scipy as sp
import math
import matplotlib.pyplot as plt
from plotly.offline import iplot
from scipy.spatial.distance import cosine
from plotly.offline import iplot
import plotly as py
import cufflinks as cf
import math 
import numpy as np
from scipy.stats import shapiro

# %%
df = pd.read_csv('file_train_senza_outliers.csv', skipinitialspace=True)

# %% [markdown]
# <h2>Standardizzazione delle variabili</h2>

# %%
colonne=["n_bars", "n_beats"]
df["n_bars"]=df["n_bars"]/df["n_bars"].max()
df["n_beats"]=df["n_beats"]/df["n_beats"].max()
df["duration_ms"]=df["duration_ms"]/1000
df["time_signature"]=df["time_signature"]/df["time_signature"].max()
df["loudness"]=df["loudness"]-df["loudness"].min()
df["loudness"]=df["loudness"]/df["loudness"].max()
df["processing"]=df["processing"]/df["processing"].max()
df["tempo"]=df["tempo"]/df["tempo"].max()
# df["key"]=df["key"]/df["key"].max()  key è un intero.
df.head()
# Out:
#    Unnamed: 0                                  name  duration_ms  explicit  \
# 0           0                             Long Road      0.24176     False
# 1           1  Daniâl My Son, Where Did You Vanish?      0.44400     False
# 2           2                    Ondskapens Galakse      0.33351     False
# 3           3                       Can't Look Away      0.26980     False
# 4           4                         Thunderground      0.30765     False
#
#                   artists              album_name  danceability  energy  key  \
# 0           Funki Porcini           Hed Phone Sex          0.69    0.51    5
# 1           Siavash Amini    A Trail of Laughters          0.07    0.20    1
# 2               Kvelertak              Nattesferd          0.36    0.85    2
# 3       The Wood Brothers       One Drop of Truth          0.52    0.58    5
# 4  The Darkraver;DJ Vince  Happy Hardcore Top 100          0.64    0.69    7
#
#    loudness  ...  acousticness  instrumentalness  liveness  valence     tempo  \
# 0  0.702221  ...          0.30              0.54      0.28     0.64  0.644930
# 1  0.469349  ...          0.28              0.93      0.36     0.03  0.342826
# 2  0.798823  ...          0.00              0.80      0.26     0.49  0.528886
# 3  0.833555  ...          0.07              0.00      0.12     0.38  0.638854
# 4  0.724805  ...          0.00              0.10      0.30     0.64  0.652821
#
#    time_signature   n_beats    n_bars  processing        genre
# 0         0.66778  0.077164  0.064977    0.314496      j-dance
# 1         0.66778  0.083968  0.071429    0.582310      iranian
# 2         0.66778  0.088732  0.074654    0.909091  black-metal
# 3         0.66778  0.084241  0.071429    0.314496    bluegrass
# 4         0.66778  0.099755  0.084332    1.000000        happy
#
# [5 rows x 22 columns]

# %%
df["loudness"].max()
# Out:
# 1.0

# %%
df["loudness"].min()
# Out:
# 0.0

# %%
df_copy=df.drop(['name', 'artists', 'album_name'], axis=1)

# %%
df_copy.head()
# Out:
#    Unnamed: 0  duration_ms  explicit  danceability  energy  key  loudness  \
# 0           0      0.24176     False          0.69    0.51    5  0.702221
# 1           1      0.44400     False          0.07    0.20    1  0.469349
# 2           2      0.33351     False          0.36    0.85    2  0.798823
# 3           3      0.26980     False          0.52    0.58    5  0.833555
# 4           4      0.30765     False          0.64    0.69    7  0.724805
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0   1.0         0.10          0.30              0.54      0.28     0.64
# 1   0.0         0.08          0.28              0.93      0.36     0.03
# 2   1.0         0.04          0.00              0.80      0.26     0.49
# 3   1.0         0.08          0.07              0.00      0.12     0.38
# 4   1.0         0.05          0.00              0.10      0.30     0.64
#
#       tempo  time_signature   n_beats    n_bars  processing        genre
# 0  0.644930         0.66778  0.077164  0.064977    0.314496      j-dance
# 1  0.342826         0.66778  0.083968  0.071429    0.582310      iranian
# 2  0.528886         0.66778  0.088732  0.074654    0.909091  black-metal
# 3  0.638854         0.66778  0.084241  0.071429    0.314496    bluegrass
# 4  0.652821         0.66778  0.099755  0.084332    1.000000        happy

# %%
genres = sorted(df['genre'].unique())
genres_mapping = dict(zip(genres, range(0, len(genres) + 1)))
genres_mapping
# Out:
# {'afrobeat': 0,
#  'black-metal': 1,
#  'bluegrass': 2,
#  'brazil': 3,
#  'breakbeat': 4,
#  'chicago-house': 5,
#  'disney': 6,
#  'forro': 7,
#  'happy': 8,
#  'idm': 9,
#  'indian': 10,
#  'industrial': 11,
#  'iranian': 12,
#  'j-dance': 13,
#  'j-idol': 14,
#  'mandopop': 15,
#  'sleep': 16,
#  'spanish': 17,
#  'study': 18,
#  'techno': 19}

# %%
df_copy['genre_val'] = df_copy['genre'].map(genres_mapping).astype(int)
df_copy.head()
# Out:
#    Unnamed: 0  duration_ms  explicit  danceability  energy  key  loudness  \
# 0           0      0.24176     False          0.69    0.51    5  0.702221
# 1           1      0.44400     False          0.07    0.20    1  0.469349
# 2           2      0.33351     False          0.36    0.85    2  0.798823
# 3           3      0.26980     False          0.52    0.58    5  0.833555
# 4           4      0.30765     False          0.64    0.69    7  0.724805
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0   1.0         0.10          0.30              0.54      0.28     0.64
# 1   0.0         0.08          0.28              0.93      0.36     0.03
# 2   1.0         0.04          0.00              0.80      0.26     0.49
# 3   1.0         0.08          0.07              0.00      0.12     0.38
# 4   1.0         0.05          0.00              0.10      0.30     0.64
#
#       tempo  time_signature   n_beats    n_bars  processing        genre  \
# 0  0.644930         0.66778  0.077164  0.064977    0.314496      j-dance
# 1  0.342826         0.66778  0.083968  0.071429    0.582310      iranian
# 2  0.528886         0.66778  0.088732  0.074654    0.909091  black-metal
# 3  0.638854         0.66778  0.084241  0.071429    0.314496    bluegrass
# 4  0.652821         0.66778  0.099755  0.084332    1.000000        happy
#
#    genre_val
# 0         13
# 1         12
# 2          1
# 3          2
# 4          8

# %%
df_copy=df_copy.drop(['genre'], axis=1)
df_copy.head()
# Out:
#    Unnamed: 0  duration_ms  explicit  danceability  energy  key  loudness  \
# 0           0      0.24176     False          0.69    0.51    5  0.702221
# 1           1      0.44400     False          0.07    0.20    1  0.469349
# 2           2      0.33351     False          0.36    0.85    2  0.798823
# 3           3      0.26980     False          0.52    0.58    5  0.833555
# 4           4      0.30765     False          0.64    0.69    7  0.724805
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0   1.0         0.10          0.30              0.54      0.28     0.64
# 1   0.0         0.08          0.28              0.93      0.36     0.03
# 2   1.0         0.04          0.00              0.80      0.26     0.49
# 3   1.0         0.08          0.07              0.00      0.12     0.38
# 4   1.0         0.05          0.00              0.10      0.30     0.64
#
#       tempo  time_signature   n_beats    n_bars  processing  genre_val
# 0  0.644930         0.66778  0.077164  0.064977    0.314496         13
# 1  0.342826         0.66778  0.083968  0.071429    0.582310         12
# 2  0.528886         0.66778  0.088732  0.074654    0.909091          1
# 3  0.638854         0.66778  0.084241  0.071429    0.314496          2
# 4  0.652821         0.66778  0.099755  0.084332    1.000000          8

# %% [markdown]
# <h2>Secondo data frame con i nan sostituiti dalla mediana</h2>

# %%
df2=df_copy.copy()

# %% [markdown]
# <h2>Terzo dataframe senza gli attributi della popolarità</h2>

# %%
df3=df2.copy()

# %%
df3=df3.drop(['explicit'], axis=1)
df3.head()
# Out:
#    Unnamed: 0  duration_ms  danceability  energy  key  loudness  mode  \
# 0           0      0.24176          0.69    0.51    5  0.702221   1.0
# 1           1      0.44400          0.07    0.20    1  0.469349   0.0
# 2           2      0.33351          0.36    0.85    2  0.798823   1.0
# 3           3      0.26980          0.52    0.58    5  0.833555   1.0
# 4           4      0.30765          0.64    0.69    7  0.724805   1.0
#
#    speechiness  acousticness  instrumentalness  liveness  valence     tempo  \
# 0         0.10          0.30              0.54      0.28     0.64  0.644930
# 1         0.08          0.28              0.93      0.36     0.03  0.342826
# 2         0.04          0.00              0.80      0.26     0.49  0.528886
# 3         0.08          0.07              0.00      0.12     0.38  0.638854
# 4         0.05          0.00              0.10      0.30     0.64  0.652821
#
#    time_signature   n_beats    n_bars  processing  genre_val
# 0         0.66778  0.077164  0.064977    0.314496         13
# 1         0.66778  0.083968  0.071429    0.582310         12
# 2         0.66778  0.088732  0.074654    0.909091          1
# 3         0.66778  0.084241  0.071429    0.314496          2
# 4         0.66778  0.099755  0.084332    1.000000          8

# %% [markdown]
# <h2>X-Means</h2>

# %%
pip install pyclustering
# Out:
# Requirement already satisfied: pyclustering in c:\users\corra\anaconda3\lib\site-packages (0.10.1.2)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\corra\anaconda3\lib\site-packages (from pyclustering) (1.11.1)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\corra\anaconda3\lib\site-packages (from pyclustering) (3.7.1)
# Requirement already satisfied: numpy>=1.15.2 in c:\users\corra\anaconda3\lib\site-packages (from pyclustering) (1.24.3)
# Requirement already satisfied: Pillow>=5.2.0 in c:\users\corra\anaconda3\lib\site-packages (from pyclustering) (9.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\corra\anaconda3\lib\site-packages (from matplotlib>=3.0.0->pyclustering) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\corra\anaconda3\lib\site-packages (from matplotlib>=3.0.0->pyclustering) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\corra\anaconda3\lib\site-packages (from matplotlib>=3.0.0->pyclustering) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\corra\anaconda3\lib\site-packages (from matplotlib>=3.0.0->pyclustering) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\corra\anaconda3\lib\site-packages (from matplotlib>=3.0.0->pyclustering) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\corra\anaconda3\lib\site-packages (from matplotlib>=3.0.0->pyclustering) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\corra\appdata\roaming\python\python39\site-packages (from matplotlib>=3.0.0->pyclustering) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\corra\anaconda3\lib\site-packages (from matplotlib>=3.0.0->pyclustering) (5.2.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\corra\anaconda3\lib\site-packages (from importlib-resources>=3.2.0->matplotlib>=3.0.0->pyclustering) (3.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\corra\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->pyclustering) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from pyclustering.cluster import cluster_visualizer
from pyclustering.cluster.xmeans import xmeans
from pyclustering.cluster.center_initializer import kmeans_plusplus_initializer
from pyclustering.utils import read_sample
from pyclustering.samples.definitions import SIMPLE_SAMPLES
from pyclustering.cluster import cluster_visualizer_multidim
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# %% [markdown]
# <h1>Dalle lezioni dello scorso anno</h1>

# %%
#scaling, normalization
from sklearn.preprocessing import StandardScaler, MinMaxScaler
#kmeans, dbscan, hierarchical (sklearn)
from sklearn.cluster import KMeans, DBSCAN, AgglomerativeClustering
#evaluation
from sklearn.metrics import silhouette_score
#import dataset
from sklearn.datasets import load_iris

#distance matrix (dbscan elbow, hierarchical)
from scipy.spatial.distance import pdist, squareform
# hierarchical (scipy)
from scipy.cluster.hierarchy import linkage, dendrogram

# %% [markdown]
# <h2>Normalizzazione</h2>

# %%
X = df2.values
scaler = StandardScaler()
scaler.fit(X)
X_scal = scaler.transform(X)

# %%
i = 2
sns.histplot(X[:,i])
plt.title(df.columns[i])
plt.xlabel("Values")
plt.show()
# Out:
# <__array_function__ internals>:200: RuntimeWarning:
#
# Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %%
i = 2
sns.histplot(X_scal[:,i])
plt.title(df2.columns[i])
plt.xlabel("Standardized values (zscore)")
plt.show()

# %%
scaler = MinMaxScaler()
X_minmax = scaler.fit_transform(X)

i = 2
sns.histplot(X_minmax[:,i])
plt.title(df2.columns[i])
plt.xlabel("Normalized values (minmax)")
plt.show()

# %% [markdown]
# <h2>K-means</h2>

# %%
kmeans = KMeans(n_clusters=5, n_init=10, max_iter=100)
kmeans.fit(X_minmax)
# Out:
# KMeans(max_iter=100, n_clusters=5, n_init=10)

# %%
centers = kmeans.cluster_centers_

# %%
centers = scaler.inverse_transform(centers)

# %%
df['kmeans_labels'] = kmeans.labels_
df['kmeans_labels'] = df['kmeans_labels'].map({0:"A", 1: "B", 2: "C", 3: "D", 4: "F"})

# %%
sns.scatterplot(data=df2, x="danceability", y="n_bars",  hue=kmeans.labels_, style=kmeans.labels_,
                palette="bright")
plt.legend()
plt.scatter(centers[:,3], centers[:,16], c='black', marker='*', s=200)
plt.show()

# %%
sns.scatterplot(data=df2, y="n_beats", x="loudness",  hue=kmeans.labels_, style=kmeans.labels_,
                palette="bright")
plt.legend()
plt.scatter(centers[:,6], centers[:,15], c='black', marker='*', s=200)
plt.show()

# %%
sns.scatterplot(data=df2, y="valence", x="tempo",  hue=kmeans.labels_, style=kmeans.labels_,
                palette="bright")
plt.legend()
plt.scatter(centers[:,13], centers[:,12], c='black', marker='*', s=200)
plt.show()

# %%
plt.figure(figsize=(10, 3))

clust_name = ['A', 'B', 'C', 'D', 'E']
for i in range(len(centers)):
    plt.plot(centers[i], marker='o', label=clust_name[i])
    
plt.xticks(range(0,len(df.columns)), df.columns, fontsize=4)
plt.yticks(fontsize=15)

plt.legend(fontsize=7, loc='best')
plt.grid(axis='y')

# %% [markdown]
# Altro tentativo

# %%
from pyclustering.cluster import xmeans

# %%
import warnings
np.warnings = warnings
xm = xmeans.xmeans(X_minmax)
xm.process()

# %%
clusters = xm.get_clusters()

# %%
def clusters_to_labels(clusters):
    labels = np.empty(shape=(len(np.concatenate(clusters))), dtype=int)
    for i in range(len(clusters)):
        for idx in clusters[i]:
            labels[idx] = i
    return labels

# %%
labels = clusters_to_labels(clusters)

# %%
centers = np.array(xm.get_centers())
centers_unscaled = scaler.inverse_transform(centers)

# %%
sns.scatterplot(data=df2, x="danceability", y="n_beats", hue=labels, palette="bright", style=labels)
plt.scatter(centers_unscaled[:, 3], centers_unscaled[:,15], color="black", marker="*", s=100)

# %%
sns.scatterplot(data=df2, y="n_beats", x="valence", hue=labels, palette="bright", style=labels)
plt.scatter(centers_unscaled[:, 12], centers_unscaled[:,15], color="black", marker="*", s=100)

# %%
sns.scatterplot(data=df2, y="loudness", x="energy", hue=labels, palette="bright", style=labels)
plt.scatter(centers_unscaled[:, 6], centers_unscaled[:, 4], color="black", marker="*", s=100)

# %% [markdown]
# <h2>DBScan</h2>

# %%
dbscan = DBSCAN(eps=0.55, min_samples=5, metric='euclidean')
dbscan.fit(X_minmax)

hist, bins = np.histogram(dbscan.labels_, bins=range(-1, len(set(dbscan.labels_)) + 1))

print('labels', dict(zip(bins, hist)))
print('silhouette', silhouette_score(df2, dbscan.labels_))
# Out:
# labels {-1: 687, 0: 10164, 1: 540, 2: 3343, 3: 203, 4: 2, 5: 15, 6: 14, 7: 7, 8: 4, 9: 5, 10: 4, 11: 4, 12: 4, 13: 4, 14: 0}
# silhouette -0.6506562418593315

# %%
sns.scatterplot(data=df2, y="valence", x="tempo",  hue=dbscan.labels_, 
                style=dbscan.labels_, palette="bright")
plt.show()

# %%
sns.scatterplot(data=df2, y="n_beats", x="loudness",  hue=dbscan.labels_, style=dbscan.labels_,
                palette="bright")
plt.show()

# %% [markdown]
# <h2></h2>

# %% [markdown]
# <h2>Kth neigbouhood distance</h2>

# %%
dist = pdist(X_minmax, 'euclidean')
dist = squareform(dist)

# %%
sns.heatmap(dist, cmap="Greens_r", annot=False)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# c:\Users\corra\Documents\GitHub\Data-Mining\dataset (missing + split)\clustering.ipynb Cella 56 line <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/corra/Documents/GitHub/Data-Mining/dataset%20%28missing%20%2B%20split%29/clustering.ipynb#Y106sZmlsZQ%3D%3D?line=0'>1</a> sns.heatmap(dist, cmap="Greens_r", annot=False)
#       <a href='vscode-notebook-cell:/c%3A/Users/corra/Documents/GitHub/Data-Mining/dataset%20%28missing%20%2B%20split%29/clustering.ipynb#Y106sZmlsZQ%3D%3D?line=1'>2</a> plt.show()
#
# File c:\Users\corra\anaconda3\lib\site-packages\seaborn\matrix.py:459, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     457 if square:
#     458     ax.set_aspect("equal")
# --> 459 plotter.plot(ax, cbar_ax, kwargs)
#     460 return ax
#
# File c:\Users\corra\anaconda3\lib\site-packages\seaborn\matrix.py:340, in _HeatMapper.plot(self, ax, cax, kws)
#     337 plt.setp(ytl, va="center")  # GH2484
#     339 # Possibly rotate them if they overlap
# --> 340 _draw_figure(ax.figure)
#     342 if axis_ticklabels_overlap(xtl):
#     343     plt.setp(xtl, rotation="vertical")
#
# File c:\Users\corra\anaconda3\lib\site-packages\seaborn\utils.py:80, in _draw_figure(fig)
#      78 """Force draw of a matplotlib figure, accounting for back-compat."""
#      79 # See https://github.com/matplotlib/matplotlib/issues/19197 for context
# ---> 80 fig.canvas.draw()
#      81 if fig.stale:
#      82     try:
#
# File c:\Users\corra\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:400, in FigureCanvasAgg.draw(self)
#     396 # Acquire a lock on the shared font cache.
#     397 with RendererAgg.lock, \
#     398      (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     399       else nullcontext()):
# --> 400     self.figure.draw(self.renderer)
#     401     # A GUI class may be need to update a window using this draw, so
#     402     # don't forget to call the superclass.
#     403     super().draw()
#
# File c:\Users\corra\anaconda3\lib\site-packages\matplotlib\artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File c:\Users\corra\anaconda3\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\corra\anaconda3\lib\site-packages\matplotlib\figure.py:3140, in Figure.draw(self, renderer)
#    3137         # ValueError can occur when resizing a window.
#    3139 self.patch.draw(renderer)
# -> 3140 mimage._draw_list_compositing_images(
#    3141     renderer, self, artists, self.suppressComposite)
#    3143 for sfig in self.subfigs:
#    3144     sfig.draw(renderer)
#
# File c:\Users\corra\anaconda3\lib\site-packages\matplotlib\image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File c:\Users\corra\anaconda3\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\corra\anaconda3\lib\site-packages\matplotlib\axes\_base.py:3064, in _AxesBase.draw(self, renderer)
#    3061 if artists_rasterized:
#    3062     _draw_rasterized(self.figure, artists_rasterized, renderer)
# -> 3064 mimage._draw_list_compositing_images(
#    3065     renderer, self, artists, self.figure.suppressComposite)
#    3067 renderer.close_group('axes')
#    3068 self.stale = False
#
# File c:\Users\corra\anaconda3\lib\site-packages\matplotlib\image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File c:\Users\corra\anaconda3\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\corra\anaconda3\lib\site-packages\matplotlib\collections.py:2074, in QuadMesh.draw(self, renderer)
#    2071     ys = self.convert_yunits(offsets[:, 1])
#    2072     offsets = np.column_stack([xs, ys])
# -> 2074 self.update_scalarmappable()
#    2076 if not transform.is_affine:
#    2077     coordinates = self._coordinates.reshape((-1, 2))
#
# File c:\Users\corra\anaconda3\lib\site-packages\matplotlib\collections.py:887, in Collection.update_scalarmappable(self)
#     885         # pcolormesh, scatter, maybe others flatten their _A
#     886         self._alpha = self._alpha.reshape(self._A.shape)
# --> 887     self._mapped_colors = self.to_rgba(self._A, self._alpha)
#     889 if self._face_is_mapped:
#     890     self._facecolors = self._mapped_colors
#
# File c:\Users\corra\anaconda3\lib\site-packages\matplotlib\cm.py:494, in ScalarMappable.to_rgba(self, x, alpha, bytes, norm)
#     492 if norm:
#     493     x = self.norm(x)
# --> 494 rgba = self.cmap(x, alpha=alpha, bytes=bytes)
#     495 return rgba
#
# File c:\Users\corra\anaconda3\lib\site-packages\matplotlib\colors.py:739, in Colormap.__call__(self, X, alpha, bytes)
#     736 if bytes:
#     737     lut = (lut * 255).astype(np.uint8)
# --> 739 rgba = lut.take(xa, axis=0, mode='clip')
#     741 if alpha is not None:
#     742     alpha = np.clip(alpha, 0, 1)
#
# MemoryError: Unable to allocate 6.71 GiB for an array with shape (225000000, 4) and data type float64
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python39\site-packages\IPython\core\formatters.py:339, in BaseFormatter.__call__(self, obj)
#     337     pass
#     338 else:
# --> 339     return printer(obj)
#     340 # Finally look for special method names
#     341 method = get_real_method(obj, self.print_method)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\IPython\core\pylabtools.py:151, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     148     from matplotlib.backend_bases import FigureCanvasBase
#     149     FigureCanvasBase(fig)
# --> 151 fig.canvas.print_figure(bytes_io, **kw)
#     152 data = bytes_io.getvalue()
#     153 if fmt == 'svg':
#
# File c:\Users\corra\anaconda3\lib\site-packages\matplotlib\backend_bases.py:2342, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2336     renderer = _get_renderer(
#    2337         self.figure,
#    2338         functools.partial(
#    2339             print_method, orientation=orientation)
#    2340     )
#    2341     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2342         self.figure.draw(renderer)
#    2344 if bbox_inches:
#    2345     if bbox_inches == "tight":
#
# File c:\Users\corra\anaconda3\lib\site-packages\matplotlib\artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File c:\Users\corra\anaconda3\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\corra\anaconda3\lib\site-packages\matplotlib\figure.py:3140, in Figure.draw(self, renderer)
#    3137         # ValueError can occur when resizing a window.
#    3139 self.patch.draw(renderer)
# -> 3140 mimage._draw_list_compositing_images(
#    3141     renderer, self, artists, self.suppressComposite)
#    3143 for sfig in self.subfigs:
#    3144     sfig.draw(renderer)
#
# File c:\Users\corra\anaconda3\lib\site-packages\matplotlib\image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File c:\Users\corra\anaconda3\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\corra\anaconda3\lib\site-packages\matplotlib\axes\_base.py:3064, in _AxesBase.draw(self, renderer)
#    3061 if artists_rasterized:
#    3062     _draw_rasterized(self.figure, artists_rasterized, renderer)
# -> 3064 mimage._draw_list_compositing_images(
#    3065     renderer, self, artists, self.figure.suppressComposite)
#    3067 renderer.close_group('axes')
#    3068 self.stale = False
#
# File c:\Users\corra\anaconda3\lib\site-packages\matplotlib\image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File c:\Users\corra\anaconda3\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\corra\anaconda3\lib\site-packages\matplotlib\collections.py:2074, in QuadMesh.draw(self, renderer)
#    2071     ys = self.convert_yunits(offsets[:, 1])
#    2072     offsets = np.column_stack([xs, ys])
# -> 2074 self.update_scalarmappable()
#    2076 if not transform.is_affine:
#    2077     coordinates = self._coordinates.reshape((-1, 2))
#
# File c:\Users\corra\anaconda3\lib\site-packages\matplotlib\collections.py:887, in Collection.update_scalarmappable(self)
#     885         # pcolormesh, scatter, maybe others flatten their _A
#     886         self._alpha = self._alpha.reshape(self._A.shape)
# --> 887     self._mapped_colors = self.to_rgba(self._A, self._alpha)
#     889 if self._face_is_mapped:
#     890     self._facecolors = self._mapped_colors
#
# File c:\Users\corra\anaconda3\lib\site-packages\matplotlib\cm.py:494, in ScalarMappable.to_rgba(self, x, alpha, bytes, norm)
#     492 if norm:
#     493     x = self.norm(x)
# --> 494 rgba = self.cmap(x, alpha=alpha, bytes=bytes)
#     495 return rgba
#
# File c:\Users\corra\anaconda3\lib\site-packages\matplotlib\colors.py:739, in Colormap.__call__(self, X, alpha, bytes)
#     736 if bytes:
#     737     lut = (lut * 255).astype(np.uint8)
# --> 739 rgba = lut.take(xa, axis=0, mode='clip')
#     741 if alpha is not None:
#     742     alpha = np.clip(alpha, 0, 1)
#
# MemoryError: Unable to allocate 6.71 GiB for an array with shape (225000000, 4) and data type float64

# %%
k=5
kth_distances = []
for d in dist:
    index_kth_distance = np.argsort(d)[k] 
    kth_distances.append(d[index_kth_distance])

# %%
plt.plot(range(0, len(kth_distances)), sorted(kth_distances))
plt.ylabel('distance from the {}th neighbor'.format(k))
         
plt.show()

# %% [markdown]
# <h2>Hierarchical</h2>

# %%
def plot_dendrogram(model, **kwargs):
    # Create linkage matrix and then plot the dendrogram

    # create the counts of samples under each node
    counts = np.zeros(model.children_.shape[0])
    n_samples = len(model.labels_)
    for i, merge in enumerate(model.children_):
        current_count = 0
        for child_idx in merge:
            if child_idx < n_samples:
                current_count += 1  # leaf node
            else:
                current_count += counts[child_idx - n_samples]
        counts[i] = current_count

    linkage_matrix = np.column_stack(
        [model.children_, model.distances_, counts]
    ).astype(float)

    # Plot the corresponding dendrogram
    dendrogram(linkage_matrix, **kwargs)

# %%
model = AgglomerativeClustering(distance_threshold=0, n_clusters=None, affinity='euclidean', linkage='complete')
model = model.fit(X_minmax)
# Out:
# c:\Users\corra\anaconda3\lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning:
#
# Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead

# %%
plt.title("Hierarchical Clustering Dendrogram")
plot_dendrogram(model, truncate_mode="lastp")
plt.xlabel("Number of points in node (or index of point if no parenthesis).")
plt.show()

# %%
hier = AgglomerativeClustering(n_clusters=3, affinity='euclidean', linkage='complete')
hier.fit(X_minmax)
# Out:
# c:\Users\corra\anaconda3\lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning:
#
# Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
# AgglomerativeClustering(affinity='euclidean', linkage='complete', n_clusters=3)

# %%
hier = AgglomerativeClustering(n_clusters=2, affinity='precomputed', linkage='complete')
hier.fit(dist)
# Out:
# c:\Users\corra\anaconda3\lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning:
#
# Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
# AgglomerativeClustering(affinity='precomputed', linkage='complete')

# %%
sns.scatterplot(data=df2, y="n_beats", x="loudness",  hue=hier.labels_, style=hier.labels_,
                palette="bright")
plt.show()

# %%
sns.scatterplot(data=df2, y="valence", x="tempo",  hue=hier.labels_, 
                style=hier.labels_, palette="bright")
plt.show()

# %% [markdown]
# Altro tentativo (da internet)

# %%
import scipy.cluster.hierarchy as shc

# %%
plt.figure(figsize=(10, 7))
plt.title("Customers Dendrogram")

# Selecting Annual Income and Spending Scores by index
# selected_data = df2.iloc[:, 1:3]
clusters = shc.linkage(df2, 
            method='ward', 
            metric="euclidean")
shc.dendrogram(Z=clusters)
plt.show()
